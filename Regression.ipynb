# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# import:
# This tells Python to bring in an external module/library so you can use its features.
#
# numpy:
# Short for Numerical Python. It's a library used for fast mathematical operations, arrays, and matrices.
#
# as np:
# This is an alias. Instead of writing numpy everywhere, you're saying:
#
# “Let me just call you np from now on.”
#
# Why we use it:
# Handles large numeric data efficiently.
#
# Used for array math like .mean(), .sum(), .reshape(), etc.
#
# Line 2: import pandas as pd
#
# pandas:
# Library used for data manipulation and analysis. Think Excel meets Python but smarter.
#
# as pd:
# Alias to make your life easier. Instead of typing pandas.read_csv(...), just type pd.read_csv(...).
#
# Why we use it:
# Handles tabular data using DataFrames (rows & columns like spreadsheets).
#
# Allows for cleaning, filtering, grouping, and analyzing data.
#
# Line 3: import matplotlib.pyplot as plt
#
# matplotlib.pyplot:
# The plotting module of matplotlib. Used to make graphs, charts, and visualizations.
#
# as plt:
# Alias — you don’t want to keep typing matplotlib.pyplot, right?
#
# Why we use it:
# To make plots like line graphs, bar charts, scatter plots, histograms, etc.

# %%
df = pd.read_csv("C://Users//Hetshree//Downloads//economic_index.csv")

# %% [markdown]
# 1. df
# Stands for DataFrame, the most powerful and commonly used object in pandas.
#
# Think of it like an Excel sheet with rows and columns.
#
# This is your variable name where the data will be stored.
#
# You can call it anything (data, my_table, economic_data), but df is the standard short name used by 99.9% of Python folks.
#
# 2.read_csv()
# Function from pandas that means:
# “Read a CSV file and turn it into a DataFrame.”
#
# csv stands for Comma-Separated Values, a plain-text table format.
#
#  5. ("C://Users//Hetshree//Downloads//economic_index.csv")
# This is the file path to your .csv file.
#
# It tells Python where the file is stored on your computer.
#
# 🔧 Important notes:
#
# Double slashes // or raw strings (r"path") are used to escape backslashes (\).
#
# The file must exist at this location, or you'll get a FileNotFoundError.
#
# What actually happens?
#
# You are:
#
# Reading a CSV file from your Downloads folder.
#
# Converting that into a pandas DataFrame.
#
# Storing that DataFrame inside a variable called df.

# %%
df.head(500)
# Out:
#     Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0            0  2017     12           2.75                5.3         1464
# 1            1  2017     11           2.50                5.3         1394
# 2            2  2017     10           2.50                5.3         1357
# 3            3  2017      9           2.50                5.3         1293
# 4            4  2017      8           2.50                5.4         1256
# 5            5  2017      7           2.50                5.6         1254
# 6            6  2017      6           2.50                5.5         1234
# 7            7  2017      5           2.25                5.5         1195
# 8            8  2017      4           2.25                5.5         1159
# 9            9  2017      3           2.25                5.6         1167
# 10          10  2017      2           2.00                5.7         1130
# ...

# %% [markdown]
# head()
# This is a pandas method.
#
# It means: “Show me the first few rows of the DataFrame.”
#
# Default: df.head() shows the first 5 rows.
#
# But since you wrote df.head(500), you're asking for the first 500 rows.
# Want the last 500 rows instead? Use df.tail(500)

# %%
df.isnull()
# Out:
#     Unnamed: 0   year  month  interest_rate  unemployment_rate  index_price
# 0        False  False  False          False              False        False
# 1        False  False  False          False              False        False
# 2        False  False  False          False              False        False
# 3        False  False  False          False              False        False
# 4        False  False  False          False              False        False
# 5        False  False  False          False              False        False
# 6        False  False  False          False              False        False
# 7        False  False  False          False              False        False
# 8        False  False  False          False              False        False
# 9        False  False  False          False              False        False
# 10       False  False  False          False              False        False
# ...

# %% [markdown]
# isnull()
# A pandas method used to check for missing values (aka NaN, aka “Not a Number”).
# Each cell will say:
#
# True → if the original cell had a missing/NaN value.
#
# False → if the cell had valid data.

# %%
df.drop(columns=["Unnamed: 0", "year", "month"], inplace=True, errors='ignore')

# %% [markdown]
# .drop()
# This is a pandas method used to remove rows or columns.
#
# Think of it like saying: “Hey df, get rid of something.”
#
#  columns=[...]
# You're specifically telling pandas:
# “Drop these columns, not rows.”
#
# This keyword clarifies your intent.
#
# 🔹 ["Unnamed: 0", "year", "month"]
# This is the list of column names you want to delete.
#
# | Option                    | What it does                                                                                  |
# | ------------------------- | --------------------------------------------------------------------------------------------- |
# | `inplace=False` (default) | Makes a **copy** of `df` with columns dropped. You'd have to reassign it: `df = df.drop(...)` |
# | `inplace=True`            | Modifies the original `df` **directly**. No need to reassign.                                 |
#
# errors='ignore'
# Life saver
#     If any of the columns I listed don’t exist, don’t throw an error. Just move on.

# %%
df.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# import seaborn as sns
#
# You’re pulling in Seaborn, the slicker, cooler cousin of matplotlib. It's like the artsy kid in the data viz family who makes charts look dope with minimal effort.
#
# sns is just a shorthand so you don’t have to type “seaborn” every time. Efficiency FTW.
#
# sns.pairplot(df)
#
# This command is the magic bullet. It creates a pairplot — a grid of scatterplots (and histograms on the diagonals) for every pair of numerical columns in your DataFrame df.
#
# Basically, it’s like your data showing off all its relationships at once — every variable paired with every other variable.
#
# For example, if you have columns A, B, C, it will plot A vs B, B vs C, A vs C, and histograms of A, B, and C on the diagonals.
#
# This is clutch for a quick eyeball check of correlations, trends, and if something’s suspiciously linear or nonlinear.

# %%
df.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %% [markdown]
# It’s a Pandas DataFrame method that calculates the correlation matrix of your numerical columns.
#
# Correlation measures how strongly two variables move together — kind of like tracking who vibes well with who in your dataset’s social circle.
# Values range from -1 to 1.
#
# +1 means a perfect positive correlation — when one goes up, the other goes up like best friends synced in a dance.
#
# -1 means a perfect negative correlation — one rises while the other falls, like a seesaw.
#
# 0 means no linear relationship — they don’t care about each other at all.
#
# |       | A     | B    | C     |
# | ----- | ----- | ---- | ----- |
# | **A** | 1.00  | 0.75 | -0.20 |
# | **B** | 0.75  | 1.00 | 0.10  |
# | **C** | -0.20 | 0.10 | 1.00  |
#
# A and B are homies (0.75),
#
# A and C are meh (-0.20),
#
# B and C barely even notice each other (0.10).

# %%
 plt.scatter(df['interest_rate'],df['unemployment_rate'],color='Red')
plt.ylabel("unemployment_rate")
plt.xlabel("interest_rate")
# Out:
# Text(0.5, 0, 'interest_rate')

# %% [markdown]
# plt.scatter()
#
# You’re plotting a scatterplot, the OG tool for showing the relationship between two variables.
#
# Here, df['interest_rate'] is your x-axis (independent variable), and df['unemployment_rate'] is your y-axis (dependent variable).
#
# The points are colored red, so they pop like a fire alarm in a library.
#
# plt.ylabel("unemployment_rate")
#
# Sets the label for the y-axis. Keeps your plot from being a cryptic mess. Clear labeling is respect for your future self and anyone else peeking at your chart.
#
# plt.xlabel("interest_rate")
#
# Same as above, but for the x-axis. You want people to know what they’re eyeballing.

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %% [markdown]
# df.iloc:
#
# .iloc is the positional indexer in pandas — think of it as slicing your data by row and column numbers (not names).
#
# Syntax: df.iloc[rows, columns]
#
# df.iloc[:, :-1]:
#
# : means take all rows.
#
# :-1 means take all columns except the last one. So basically, grab every column but drop the last.
#
# This chunk is your features matrix — all the inputs your model or analysis will use to predict something
#
# df.iloc[:, -1]:
#
# Again, : is all rows.
#
# -1 means the last column only.
#
# This is your target vector — the thing you want to predict or analyze.

# %%
x.head()
# Out:
#    interest_rate  unemployment_rate
# 0           2.75                5.3
# 1           2.50                5.3
# 2           2.50                5.3
# 3           2.50                5.3
# 4           2.50                5.4

# %%
y
# Out:
# 0     1464
# 1     1394
# 2     1357
# 3     1293
# 4     1256
# 5     1254
# 6     1234
# 7     1195
# 8     1159
# 9     1167
# 10    1130
# 11    1075
# 12    1047
# 13     965
# 14     943
# 15     958
# 16     971
# 17     949
# 18     884
# 19     866
# 20     876
# 21     822
# 22     704
# 23     719
# Name: index_price, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# from sklearn.model_selection: You're grabbing tools from the model_selection module of sklearn, which is scikit-learn — your ML homie 💻🤖.
#
# import train_test_split: You're importing a function named train_test_split — this is the magical slicer that divides your data into two parts:
#
#  training data → model learns here
#
#  testing data → model gets grilled here
#
# x: This is your features or inputs (think: number of rooms, unemployment rate, etc.)
#
# y: This is your target/output (think: price, success, etc.)
#
# train_test_split() call:
#
# test_size=0.25:
#
# You're saying “Yo, take 25% of the data and save it for testing.”
#
# That means: 75% = training, 25% = testing.
#
# random_state=42:
#
# This is the seed. Not a real tree seed — but a digital one 🌱
#
# It makes sure that every time you run the code, the split is exactly the same. Think of it like locking in your deck of cards so the shuffle always matches.
#
# Why 42? It's a nerdy easter egg. Douglas Adams, The Hitchhiker's Guide to the Galaxy — answer to everything = 42
#
# x_train: 75% of input data (used to train)
#
# x_test: 25% of input data (used to test)
#
# y_train: 75% of target/labels
#
# y_test: 25% of target/labels

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# from sklearn.preprocessing
# You're diving into the preprocessing module of scikit-learn, which is basically the “✨ beauty salon” of your data pipeline.
# Why? Because raw data is messy — some features be rich, some poor (in scale). We can't have that inequality, nah.
#
# 🔹 import StandardScaler
# You’re importing the StandardScaler class. This baby is your data standardizer.
#
# What does StandardScaler actually do?
# It standardizes features by removing the mean and scaling to unit variance.

# %%
scaler=StandardScaler()

# %% [markdown]
# scaler
# This is just a variable name you're creating. StandardScaler()
# You’re creating an object (a.k.a. instance) of the StandardScaler class.

# %%
x_train=scaler.fit_transform(x_train)

# %% [markdown]
# x_train
# This is your training feature dataset — the part of your input data the model will learn from.
# scaler.fit_transform(...)
# This is the real MVP combo move — two actions in one:
#
# fit() – Calculates the mean and standard deviation of each feature column in x_train.
#
#  Think of it as: "Let me understand the vibe (statistics) of this data."
#
# transform() – Uses that info to standardize every value

# %%
x_test=scaler.fit_transform(x_test)
x_train
# Out:
# array([[-0.90115511,  0.37908503],
#        [ 1.31077107, -1.48187786],
#        [-0.90115511,  1.30956648],
#        [ 1.31077107, -0.55139641],
#        [ 1.31077107, -1.48187786],
#        [-0.16384638,  0.68924552],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -1.48187786],
#        [ 1.31077107, -1.17171738],
#        [-0.90115511,  1.30956648],
#        [-0.90115511,  0.999406  ],
#        [-0.90115511,  0.37908503],
#        [-0.90115511,  0.999406  ],
#        [ 0.57346234, -0.8615569 ],
#        [-0.16384638, -0.24123593],
#        [-0.90115511,  0.06892455],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -0.8615569 ]])

# %% [markdown]
# This means you’re calculating new means and standard deviations based on test data, which your model should NOT have seen.

# %%
sns.regplot(x='interest_rate', y='index_price', data=df)
plt.show()

# %% [markdown]
# This is your nickname for Seaborn (imported via import seaborn as sns). It's your visual buddy who makes Matplotlib look like it went to art school
#
# regplot
# This is short for regression plot.
#
# It does two things:
#
# Scatter plot of your points (like regular plt.scatter)
#
# Best-fit regression line (drawn through the cloud of points using linear regression)
#
# Dots = actual data points
#
# Line = the linear relationship Seaborn thinks exists between x and y
#
#  x='interest_rate', y='index_price'
# plt.show()
# This just forces the graph to pop up.
#
# something want different :
#
# Dots on the canvas, truth revealed,
# A line runs through, statistics sealed.
# Between rate and price, the bond is drawn,
# Seaborn whispers: "Correlation’s on."

# %%
sns.regplot(x='interest_rate', y='unemployment_rate', data=df)
plt.show()

# %% [markdown]
# As interest rates change, what happens to unemployment? Do they move together? Do they clash?

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %% [markdown]
# You're summoning the LinearRegression class from the linear_model module inside scikit-learn.

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# .fit() means: “Train yourself using this data.”
#
# It finds the best coefficients (slopes) for each feature so that the line best predicts the y_train values from x_train.

# %%
from sklearn.model_selection import cross_val_score
validation_score=cross_val_score(reg,x_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %% [markdown]
# You're importing cross_val_score, a function that lets you run cross-validation — which is like giving your model multiple mini-exams to make sure it's not just lucky.
# validation_score = ...
# You’re storing the result (a list of scores) into a variable. Each element in this list will be the MSE (Mean Squared Error) from one fold of the cross-validation.
#
#  cross_val_score(...)
# This is the magic trick:
#
# It splits your data into cv folds (in this case, cv=5)
#
# Trains the model on 4 folds, tests on the 5th — and does this 5 times (rotating the folds each time)
# Returns an array of scores (one for each fold)
#
# Basically: it's like testing your model in 5 different alternate universes
# scoring='neg_mean_squared_error'
# Scikit-learn, in its "I think I’m clever" phase, returns negative MSE when scoring lower-is-better metrics like MSE.
#
# So yeah — don’t panic when you see negative values. You can convert them later using -validation_score.

# %%
np.mean(validation_score)
# Out:
# -5649.115244350761

# %% [markdown]
# np.mean() — that's NumPy’s way of saying, "Hey, give me the average value of this array or list." Here, validation_score is probably an array of numbers, like scores from each fold in your cross-validation.
#
# So what does this do?
#
# It takes all those individual validation scores from your cross-validation runs and spits out their average.
#
# This average score tells you, roughly, how your model is performing across all the folds, smoothing out any weird highs or lows.

# %%
y_pred=reg.predict(x_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# y_pred = reg.predict(x_test)
# You’re telling your trained regression model (reg) to go on the battlefield and predict the target values for your test dataset (x_test). It’s like sending your student to guess the answers on a new exam based on what they studied.
#
# from sklearn.metrics import mean_absolute_error, mean_squared_error
# Here you’re importing two heavy hitters from scikit-learn’s toolbox to judge how good (or bad) your model’s predictions are:
#
# Mean Absolute Error (MAE): The average absolute difference between what your model predicted and the real values. This one is straightforward — how far off, on average, is your prediction?
#
# Mean Squared Error (MSE): Similar to MAE but punishes bigger errors more heavily by squaring the differences. It’s like saying “Big mistakes? Not on my watch.”

# %%
mse = mean_squared_error(y_test,y_pred)
mae= mean_absolute_error(y_test,y_pred)
rmse = np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 8108.567426306611
# 73.80444932337099
# 90.04758423359624

# %% [markdown]
# mse = mean_squared_error(y_test, y_pred)
# Calculates the average of squared differences between actual values (y_test) and your predictions (y_pred). Squaring means big mistakes hurt way more, so it’s sensitive to outliers.
# Lower is better. MSE = 0 means perfect predictions — but come on, that’s rare.
#
# mae = mean_absolute_error(y_test, y_pred)
# Averages the absolute difference between actuals and predictions — treats all errors equally. Gives you a more “human-friendly” sense of average error. Also, lower = better.
#
# rmse = np.sqrt(mse)
# Root Mean Squared Error is just the square root of MSE — this brings the error back to the original units (instead of squared units). It’s easier to interpret because it’s on the same scale as your target variable.

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# What this scatter plot shows:
# X-axis: The actual true values from your test set (y_test).
#
# Y-axis: The predicted values your model spat out (y_pred).
#
# What to look for?
#
# Ideally, points should lie right on the diagonal line y = x — because that means predicted = actual, spot on!
#
# If points scatter all over, your model’s got some explaining to do.
#
# Clusters away from the diagonal? Model bias or variance showing its ugly face.
#
# Systematic curves or patterns? Might mean your model is missing some key info or relationships.

# %%
residuals=y_test-y_pred
print(residuals)
# Out:
# 8     -21.746681
# 16    168.257203
# 0      84.165430
# 18     45.474004
# 11    101.146860
# 9      22.036518
# Name: index_price, dtype: float64

# %% [markdown]
# residuals = y_test - y_pred
# You calculated the difference between the actual values and what your model predicted. Basically, residuals are your model’s oops moments — how far off it was on each prediction.
#
# print(residuals)
# You're now looking at those errors laid bare. Each value shows whether your prediction was too high (negative residual) or too low (positive residual).
#
# Why residuals matter:
# If residuals look like random noise (no pattern), your model is probably doing its job right.
#
# But if residuals show some pattern (like a curve or trend), your model might be missing some hidden magic in the data — time to rethink your features or model.

# %%
sns.displot(residuals,kind='kde')

# %% [markdown]
# What you’re doing here:
# You’re plotting a Kernel Density Estimate (KDE) of your residuals — basically a smooth curve showing how residuals spread out.
#
# Ideally, residuals should look like a normal (bell-shaped) curve centered at zero. That means errors are mostly small and symmetrically distributed around zero — model behaving like a well-trained.
# What to watch for:
# Symmetry & Centering: If the curve peaks at zero and is symmetric, nice job!
#
# Skewed or off-centered: Means bias — model consistently over or underpredicting.
#
# Multiple peaks or weird shapes: Uh-oh, your model might be missing key patterns or suffering from weird noise.

# %%
plt.scatter(y_pred,residuals)

# %% [markdown]
# What to watch out for:
# No pattern, random cloud: Your model’s errors are likely independent of predicted values — good sign!
#
# Clear patterns (like a funnel or curve): Uh-oh, that means heteroscedasticity (errors’ variance changes with prediction) or model missing something — not ideal!
#
# Clusters or trends: Could indicate model bias, bad fit, or non-linearity. Time to level up the model.

# %%
import statsmodels.api as sm
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()

# %% [markdown]
# import statsmodels.api as sm
# Pulling in the big gun for statistical modeling. Statsmodels is the OG library if you want full control and detailed regression results — no sugarcoating, just cold hard stats.
#
# x = sm.add_constant(x)
# This adds the intercept term (the constant) to your features matrix. Unlike scikit-learn, statsmodels won’t automatically include it, so you gotta explicitly add this column of 1s. Otherwise, your regression line will be forced through the origin — yikes.
#
# model = sm.OLS(y, x).fit()
# You’re telling statsmodels:
# “Here’s my dependent variable y and independent variables x. Fit me an Ordinary Least Squares (OLS) linear regression model.”

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            index_price   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.888
# Method:                 Least Squares   F-statistic:                     92.07
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):           4.04e-11
# Time:                        14:01:16   Log-Likelihood:                -134.61
# No. Observations:                  24   AIC:                             275.2
# Df Residuals:                      21   BIC:                             278.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# model.summary()! This command spits out the full regression report like a boss, giving you the inside scoop on how your model is flexing.
#
# What to expect in the summary:
# R-squared & Adj. R-squared:
# How much of the variation in your dependent variable your model explains. Closer to 1 = better fit. Adjusted version punishes you for too many useless features.
#
# Coefficients:
# The effect size of each feature on the target variable. Positive means it pushes your target up; negative means it drags it down.
#
# Standard Errors:
# How “sure” the model is about each coefficient. Smaller = more confidence.
#
# t-statistics & p-values:
# Hypothesis test results. p-values < 0.05 usually mean that feature actually matters — no BS.
#
# F-statistic:
# Overall significance of the model — are your predictors working together or just noise?
#
# Diagnostic stuff:
# Durbin-Watson for autocorrelation, Omnibus test for normality, Jarque-Bera test — basically, how clean and trustworthy your model assumptions are.

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# df.corr()
# Calculates the correlation matrix of your DataFrame. Basically, it’s a grid showing how each variable vibes with every other variable on a scale from -1 to 1.
#
# +1 means best friends (perfect positive correlation)
#
# -1 means arch enemies (perfect negative correlation)
#
# 0 means ghosting (no correlation)
#
# sns.heatmap(..., annot=True)
# Plots that matrix as a colorful grid with numbers printed inside the cells. Colors help you instantly spot strong relationships or suspiciously quiet ones.
